# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import datetime

datetime_object = datetime.datetime.now()
print(datetime_object)
# Out:
# 2022-01-20 21:11:07.667592

# %%
import datetime as dt

# %%
# File to load
nc_covid_data_to_load = 'C:/Users/cihan/Desktop/UNC CHAPEL HILL DATA ANALYTICS/Module20 Final Project/Data_source/nc_covid_data.csv'

nc_covid_data_df = pd.read_csv(nc_covid_data_to_load)

# Display data
nc_covid_data_df.head(500)
# Out:
#      Unnamed: 0 case_month res_state  state_fips_code   res_county  \
# 0            50    2021-09        NC               37   CUMBERLAND
# 1           158    2021-08        NC               37  MECKLENBURG
# 2           225    2021-09        NC               37   CUMBERLAND
# 3           402    2021-09        NC               37   CUMBERLAND
# 4           519    2021-08        NC               37  MECKLENBURG
# ..          ...        ...       ...              ...          ...
# 495       61970    2021-08        NC               37   CUMBERLAND
# 496       61987    2021-09        NC               37  MECKLENBURG
# 497       62077    2021-07        NC               37         WAKE
# 498       62146    2021-08        NC               37   CUMBERLAND
# 499       62249    2021-07        NC               37         WAKE
#
#      county_fips_code       age_group     sex            race  \
# 0             37051.0    0 - 17 years  Female           Black
# ...

# %%
nc_covid_data_df.dtypes
# Out:
# Unnamed: 0                           int64
# case_month                          object
# res_state                           object
# state_fips_code                      int64
# res_county                          object
# county_fips_code                   float64
# age_group                           object
# sex                                 object
# race                                object
# ethnicity                           object
# case_positive_specimen_interval    float64
# current_status                      object
# symptom_status                      object
# hosp_yn                             object
# death_yn                            object
# dtype: object

# %%
nc_covid_data_df.head()
# Out:
#    Unnamed: 0 case_month res_state  state_fips_code   res_county  \
# 0          50    2021-09        NC               37   CUMBERLAND
# 1         158    2021-08        NC               37  MECKLENBURG
# 2         225    2021-09        NC               37   CUMBERLAND
# 3         402    2021-09        NC               37   CUMBERLAND
# 4         519    2021-08        NC               37  MECKLENBURG
#
#    county_fips_code       age_group     sex   race            ethnicity  \
# 0           37051.0    0 - 17 years  Female  Black  Non-Hispanic/Latino
# 1           37119.0  18 to 49 years    Male  White      Hispanic/Latino
# 2           37051.0    0 - 17 years  Female  Black  Non-Hispanic/Latino
# 3           37051.0    0 - 17 years  Female  Black  Non-Hispanic/Latino
# 4           37119.0  18 to 49 years    Male  White      Hispanic/Latino
#
#    case_positive_specimen_interval             current_status symptom_status  \
# ...

# %%
nc_covid_data_df.describe()
# Out:
#          Unnamed: 0  state_fips_code  county_fips_code  \
# count  9.365000e+03           9365.0       9365.000000
# mean   5.153865e+05             37.0      37104.141698
# std    3.092063e+05              0.0         38.753706
# min    5.000000e+01             37.0      37051.000000
# 25%    2.373280e+05             37.0      37081.000000
# 50%    5.016200e+05             37.0      37081.000000
# 75%    7.903330e+05             37.0      37119.000000
# max    1.048462e+06             37.0      37183.000000
#
#        case_positive_specimen_interval
# count                      9365.000000
# mean                          0.237053
# std                           0.644344
# min                         -20.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           0.000000
# max                          17.000000
